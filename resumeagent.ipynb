# %%
# !pip install fastapi uvicorn pymongo weasyprint jinja2 nest_asyncio pyngrok
# Out:
# Requirement already satisfied: fastapi in d:\conda\lib\site-packages (0.116.1)
# Requirement already satisfied: uvicorn in d:\conda\lib\site-packages (0.35.0)
# Requirement already satisfied: pymongo in d:\conda\lib\site-packages (4.15.0)
# Requirement already satisfied: weasyprint in d:\conda\lib\site-packages (66.0)
# Requirement already satisfied: jinja2 in d:\conda\lib\site-packages (3.1.4)
# Requirement already satisfied: nest_asyncio in d:\conda\lib\site-packages (1.6.0)
# Requirement already satisfied: pyngrok in d:\conda\lib\site-packages (7.3.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in d:\conda\lib\site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in d:\conda\lib\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\conda\lib\site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: click>=7.0 in d:\conda\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in d:\conda\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\conda\lib\site-packages (from pymongo) (2.8.0)
# Requirement already satisfied: pydyf>=0.11.0 in d:\conda\lib\site-packages (from weasyprint) (0.11.0)
# Requirement already satisfied: cffi>=0.6 in d:\conda\lib\site-packages (from weasyprint) (1.17.1)
# Requirement already satisfied: tinyhtml5>=2.0.0b1 in d:\conda\lib\site-packages (from weasyprint) (2.0.0)
# Requirement already satisfied: tinycss2>=1.4.0 in d:\conda\lib\site-packages (from weasyprint) (1.4.0)
# Requirement already satisfied: cssselect2>=0.8.0 in d:\conda\lib\site-packages (from weasyprint) (0.8.0)
# Requirement already satisfied: Pyphen>=0.9.1 in d:\conda\lib\site-packages (from weasyprint) (0.17.2)
# Requirement already satisfied: Pillow>=9.1.0 in d:\conda\lib\site-packages (from weasyprint) (10.4.0)
# Requirement already satisfied: fonttools>=4.0.0 in d:\conda\lib\site-packages (from fonttools[woff]>=4.0.0->weasyprint) (4.51.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\conda\lib\site-packages (from jinja2) (2.1.3)
# Requirement already satisfied: PyYAML>=5.1 in d:\conda\lib\site-packages (from pyngrok) (6.0.1)
# Requirement already satisfied: pycparser in d:\conda\lib\site-packages (from cffi>=0.6->weasyprint) (2.21)
# Requirement already satisfied: colorama in d:\conda\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: webencodings in d:\conda\lib\site-packages (from cssselect2>=0.8.0->weasyprint) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in d:\conda\lib\site-packages (from fonttools[woff]>=4.0.0->weasyprint) (0.2.3.post1)
# Requirement already satisfied: brotli>=1.0.1 in d:\conda\lib\site-packages (from fonttools[woff]>=4.0.0->weasyprint) (1.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\conda\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in d:\conda\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\conda\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)

# %%
from fastapi import FastAPI
from pymongo import MongoClient
import os, re
from jinja2 import Environment, FileSystemLoader
from weasyprint import HTML
import nest_asyncio
from pyngrok import ngrok
import uvicorn
# Out:
# -----
#
# WeasyPrint could not import some external libraries. Please carefully follow the installation steps before reporting an issue:
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#installation
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#troubleshooting
#
# -----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 5
#       3 import os, re
#       4 from jinja2 import Environment, FileSystemLoader
# ----> 5 from weasyprint import HTML
#       6 import nest_asyncio
#       7 from pyngrok import ngrok
#
# File d:\conda\Lib\site-packages\weasyprint\__init__.py:433
#     430         yield 'string', string, base_url, None
#     432 # Work around circular imports.
# --> 433 from .css import preprocess_stylesheet  # noqa: I001, E402
#     434 from .html import (  # noqa: E402
#     435     HTML5_UA_COUNTER_STYLE, HTML5_UA_STYLESHEET, HTML5_UA_FORM_STYLESHEET,
#     436     HTML5_PH_STYLESHEET)
#     437 from .document import Document, Page
#
# File d:\conda\Lib\site-packages\weasyprint\css\__init__.py:28
#      26 from ..urls import URLFetchingError, get_url_attribute, url_join
#      27 from . import counters, media_queries
# ---> 28 from .computed_values import COMPUTER_FUNCTIONS
#      29 from .properties import INHERITED, INITIAL_NOT_COMPUTED, INITIAL_VALUES, ZERO_PIXELS
#      30 from .validation import preprocess_declarations
#
# File d:\conda\Lib\site-packages\weasyprint\css\computed_values.py:9
#       6 from tinycss2.color4 import parse_color
#       8 from ..logger import LOGGER
# ----> 9 from ..text.ffi import FROM_UNITS, ffi, pango
#      10 from ..text.line_break import Layout, first_line_metrics
#      11 from ..urls import get_link_attribute
#
# File d:\conda\Lib\site-packages\weasyprint\text\ffi.py:475
#     472         with suppress((OSError, FileNotFoundError)):
#     473             os.add_dll_directory(dll_directory)
# --> 475 gobject = _dlopen(
#     476     ffi, 'libgobject-2.0-0', 'gobject-2.0-0', 'gobject-2.0',
#     477     'libgobject-2.0.so.0', 'libgobject-2.0.dylib', 'libgobject-2.0-0.dll')
#     478 pango = _dlopen(
#     479     ffi, 'libpango-1.0-0', 'pango-1.0-0', 'pango-1.0', 'libpango-1.0.so.0',
#     480     'libpango-1.0.dylib', 'libpango-1.0-0.dll')
#     481 harfbuzz = _dlopen(
#     482     ffi, 'libharfbuzz-0', 'harfbuzz', 'harfbuzz-0.0',
#     483     'libharfbuzz.so.0', 'libharfbuzz.0.dylib', 'libharfbuzz-0.dll')
#
# File d:\conda\Lib\site-packages\weasyprint\text\ffi.py:463, in _dlopen(ffi, allow_fail, *names)
#     453 # Re-raise the exception.
#     454 print(
#     455     '\n-----\n\n'
#     456     'WeasyPrint could not import some external libraries. Please '
#    (...)
#     461     'first_steps.html#troubleshooting',
#     462     '\n\n-----\n')  # pragma: no cover
# --> 463 return ffi.dlopen(names[0], flags)
#
# File d:\conda\Lib\site-packages\cffi\api.py:150, in FFI.dlopen(self, name, flags)
#     147     raise TypeError("dlopen(name): name must be a file name, None, "
#     148                     "or an already-opened 'void *' handle")
#     149 with self._lock:
# --> 150     lib, function_cache = _make_ffi_library(self, name, flags)
#     151     self._function_caches.append(function_cache)
#     152     self._libraries.append(lib)
#
# File d:\conda\Lib\site-packages\cffi\api.py:834, in _make_ffi_library(ffi, libname, flags)
#     832 def _make_ffi_library(ffi, libname, flags):
#     833     backend = ffi._backend
# --> 834     backendlib = _load_backend_lib(backend, libname, flags)
#     835     #
#     836     def accessor_function(name):
#
# File d:\conda\Lib\site-packages\cffi\api.py:829, in _load_backend_lib(backend, name, flags)
#     827     if first_error is not None:
#     828         msg = "%s.  Additionally, %s" % (first_error, msg)
# --> 829     raise OSError(msg)
#     830 return backend.load_library(path, flags)
#
# OSError: cannot load library 'libgobject-2.0-0': error 0x7e.  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libgobject-2.0-0'
